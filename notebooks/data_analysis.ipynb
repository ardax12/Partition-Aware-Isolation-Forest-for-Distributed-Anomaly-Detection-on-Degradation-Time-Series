# %%
from src.load_data import *
from src.rul import *
from src.visualization import *

spark = create_spark_session()

train = load_training_data(spark)

train = create_rul(train)

# %%
plot_cycle_distribution(train)

# %%
plot_rul_distribution(train)

# %%
plot_engine_lifetimes(train)

# %%
plot_sensor(train,1,"sensor11")

# %%
plot_sensor(train,1,"sensor4")

# %%
plot_engine_rul(train,1)

# %%
correlation_matrix(train)
